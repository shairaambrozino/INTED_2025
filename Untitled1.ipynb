# %% [markdown]
# <a href="https://colab.research.google.com/github/shairaambrozino/INTED_2025/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
numero = int(input('digite um numero: '))
if numero > 10:
  print('numero maior do que 10')
elif numero == 10:
  print('numero e 10')
else:
  print('numero menor que 10')
# Out:
# digite um numero: 12
# numero maior do que 10

# %%
#2
num=int(input('digite um numero:'))
if num%2==0:
  print('par')
# Out:
# digite um numero:2
# par

# %%
#3
nome=input('digite um nome')
if 'a' in nome:
  print('contem a')
# Out:
# digite um nomeshaira
# contem a

# %%
#4
num=int(input('digite a temperatura'))
if num%5==0:
  print('multiplo')
# Out:
# digite a temperatura35
# multiplo

# %%
#5
num=int(input('digite a temperatura'))
if num>30:
  print(num,'quente')
elif num<30:
  print('frio')
# Out:
# digite a temperatura36
# 36 quente

# %%
#6
letra= input('S para sair e N para continuar')
if letra.lower()=='S':
  print('sair')
if letra.lower()=='N':
  print('continuar')
else:
  print('opcao invalida')
# Out:
# S para sair e N para continuars
# opcao invalida

# %%
#7
num=int(input('digite um numero'))
if num<0:
  print(num,'negativo')
elif num>0:
 print(num,'positivo')
else:
  print(num,'zero')
# Out:
#   File "/tmp/ipython-input-454099852.py", line 5
#     elif num>0
#               ^
# SyntaxError: expected ':'
